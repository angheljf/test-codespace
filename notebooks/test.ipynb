# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

pd.set_option('display.max_columns', 500)

plt.style.use('bmh')

# %%
column_subset = ['FlightDate',
                 'Airline',
                 'Origin',
                 'Dest',
                 'Cancelled',
                 'Diverted',
                 'CRSDepTime',
                 'DepTime',
                 'DepDelayMinutes', 
                 'OriginAirportID',
                 'OriginStateName',
                 'DestAirportID',
                 'DestCityName',
                 'DestStateName',
                ]

parquet_file = "/workspaces/test-codespace/data/Combined_Flights_2021.parquet"

df2021 = pd.read_parquet(parquet_file, columns=column_subset)
df2021 = df2021.reset_index(drop=True)
df2021.head()
# Out:
#   FlightDate                Airline Origin Dest  Cancelled  Diverted  \
# 0 2021-03-03  SkyWest Airlines Inc.    SGU  PHX      False     False
# 1 2021-03-03  SkyWest Airlines Inc.    PHX  SGU      False     False
# 2 2021-03-03  SkyWest Airlines Inc.    MHT  ORD      False     False
# 3 2021-03-03  SkyWest Airlines Inc.    DFW  TRI      False     False
# 4 2021-03-03  SkyWest Airlines Inc.    PHX  BFL      False     False
#
#    CRSDepTime  DepTime  DepDelayMinutes  OriginAirportID OriginStateName  \
# 0         724    714.0              0.0            14794            Utah
# 1         922    917.0              0.0            14107         Arizona
# 2        1330   1321.0              0.0            13296   New Hampshire
# 3        1645   1636.0              0.0            11298           Texas
# 4        1844   1838.0              0.0            14107         Arizona
#
#    DestAirportID                        DestCityName DestStateName
# ...
